# %%
import numpy as np

# %%
arr=np.array([10,20,30,40])
arr

# %%
arr2=np.array([10,3.14,20,])
arr2

# %%
arr3=np.array([10,3.14,'a'])
arr3

# %%
type(arr3)

# %%
arr3.shape

# %%
arr3.ndim

# %%
arr2d=np.arange(1,13).reshape((4,3))
arr2d

# %%
arr2d.shape

# %%
arr2d.ndim

# %%
arr3d=np.arange(1,25).reshape((2,4,3))
arr3d

# %%
arr4d=np.arange(1,73).reshape((3,2,4,3))
arr4d

# %%
arr3d.shape

# %%
arr3d.size

# %%
arr4d.size

# %%
arr4d.shape

# %%
arr4d.ndim

# %%
arr3d.ndim

# %%
arr5d=np.arange(1,97).reshape((2,2,2,3,4))
arr5d

# %%
arrr3d=np.arange(1,9).reshape((4,1,2))
arrr3d

# %%
arr2d=np.arange(1,13).reshape((4,3))
arr2d

# %%
arr3d=np.arange(1,25).reshape((2,4,3))
arr3d

# %%
arr3d[0]

# %%
arr2d=np.arange(1,13).reshape((4,3))
arr2d

# %%
arr2d[0]

# %%
arr2d[0:2]

# %%
arr2d[0:3,0:2]

# %%
arr3=np.arange(1,43).reshape((6,7))
arr3

# %%
arr3[1:4, 1:4]

# %%
arr3[:,:-1]

# %%
arr3[:,-1]

# %%
arr3[[0,2,5]]

# %%
arr3[[0,3,4]]

# %%
arr3[:,[0,2,4]]
