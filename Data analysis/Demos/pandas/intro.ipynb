# %% [markdown]
# #### pandas introduction
#
#  # 1.powerful pyton data analysis liabraries.
#  # 2.behind numpy array is implimented.
#  # 3.used for load datasets (from files eg.csv,tsv,excel tec.)

# %% [markdown]
# ### data structure
# # 1.series (1d)
# # 2.dataframe (2d)
# # 3.panel (3d)
